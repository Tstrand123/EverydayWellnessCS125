# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
import json # for storing and managing data
from sklearn.metrics.pairwise import cosine_similarity
from surprise import SVD, Reader, Dataset, accuracy
from surprise.model_selection import train_test_split
#import surprise #note: package name to download is "scikit-surprise" but the actual module is just "surprise"

# sources:
#    https://towardsdatascience.com/recommendation-systems-explained-a42fc60591ed
#    https://www.datacamp.com/tutorial/recommender-systems-python
       
# TODO:
    # figure out how to include this into the repo
    # figure out how we want to store the CSVs into the database
    # figure out how the below code might need to be modified to make it work with the database
    # get more test/verif data to improve rmse
    # process NAME field and include it in the content similarity portion
    # figure out why libreCalc is constantly overwriting the CSVs and getting them mixed up
    # set up pre/post filtering to restrict results to things like "low-carb" "vegetarian" etc

# %%
if __name__ == '__main__':
    PATH = "MLData\dummyDataForApp.csv"#TODO: enter path to the data
    PATH_RATINGS = "MLData\mealRatings.csv"

# %%
#import data
df = pd.read_csv(PATH)
df_ratings = pd.read_csv(PATH_RATINGS)
#PANDAS -> DataFrame: 
    # can generate df from table or json, excel file, sql, etc
    # it seems like firebase can have an array-typed field, so we can assume that they are going to be stored as an array of strings

# this is all processing that should be done separately, like, when it is entered into the db as arrays
# loop through each entry
for i in range(0,df.shape[0]):
    # tokenize string to make a list, remove stop words, stemm, etc
    df.at[i, 'MAIN FLAVORS'] = df.at[i, 'MAIN FLAVORS'].split(',')
    df.at[i, 'TAGS'] = df.at[i, 'TAGS'].split(',')
    
    # readd to df as lists instead

#df.explode('MAIN FLAVORS') # does not work, not intrepreted as a list-like
#print(df_ratings) # data extracted correctly
#print(df.dtypes)

# %%
#content based similarity

#rmat = df_ratings.pivot_table(columns = 'meal_id', index= 'user_id', values='rating').fillna(0)
#print(rmat)

#cosine_sim = cosine_similarity(rmat, rmat)

# %%
#from sklearn.feature_extraction.text import TfidfVectorizer
def clean_data(x):
    if isinstance(x, list):
        return[str.lower(i.replace(" ", "")) for i in x]
    
features = ['MAIN FLAVORS', 'TAGS']

for f in features:
    df[f] = df[f].apply(clean_data)


#print(df)

# %%
# remove stop words and symbols from NAME so we can factor it into the features
#nltk.download("stopwords")

def processName(x):
    #print(x)
    stop = set(stopwords.words('english'))
    good_words = []
    for word in x:
        if word not in stop:
            good_words.append(word)
    return good_words

df['NAME'] = df['NAME'].apply(processName)

print(df)
# Out:
#     meal_id                                               NAME  CALORIES  \
# 0         0                        [r, e, n,  , n, l, e,  , l]       292
# 1         1                           [C, h, u, l, e,  , G, u]       516
# 2         2                              [r, e, l, l, n,  , l]       186
# 3         3      [b, e, e, f,  , n,  ,  , r, c, e,  , b, w, l]       612
# 4         4  [p, e, n, u,  , n, l, e,  , w, h,  , c, h, c, ...       727
# 5         5            [u, h, w, e,  , f, u,  , c, r, b, l, e]       176
# 6         6            [S, u, g, e,  , p, e, p, p, e, r,  , p]       517
# 7         7      [p, n, c, h,  , r, e, l, l, n,  , k, l, l, e]       648
# 8         8                           [n, k, e,  , f, h,  , c]       293
# 9         9  [B, l, c, k, e, n, e,  , l, p,  , w, h,  , z, ...       203
# 10       10               [A, p, r, g, u, -, u, h, r,  , f, r]       130
# 11       11                  [g, e,  , r, u, b, b, e,  , l, n]       220
# 12       12                  [c, h, c, k, e, n,  , n, e,  , l]       289
# 13       13               [V, e, g, e, r, n,  , e, n, c, h, l]       547
# 14       14      [l, e, n, l,  , w, h,  , u, h, r,  , g, r, v]       441
# 15       15            [R, e,  , c, u, l, f, l, w, e, r,  , l]       374
# 16       16  [ , h, e, r, b,  , r, c, e,  , w, h,  , w, h, ...       316
# 17       17      [p, u, r, p, l, e,  , p, w, e, r,  , b, w, l]       474
# 18       18  [L, e, n,  , p, e, p, p, e, r,  , c, h, c, k, ...       253
# 19       19            [N, -, b, k, e,  , g, r, n, l,  , b, r]       285
# 20       20  [L, e, n, -, B, r, c, c, l,  , p,  , w, h,  , ...       210
# 21       21            [S, e,  , B,  , w, h,  , c, r, u,  , l]       298
# 22       22  [h, e, e,  , p, n,  , h, r, p, ,,  , p, n, e, ...       505
# 23       23         [q, u, c, k,  , c, h, c, k, e, n,  , f, j]       413
# 24       24  [S, r, r, c, h, -, b, u, f, f, l,  , c, u, l, ...        99
# 25       25  [c, h, e, e,  , p, n, c, h,  , n,  , r, c, h, ...       223
# 26       26  [c, u, l, f, l, w, e, r,  , k, k,  , l,  , w, ...       268
# 27       27            [R, e, r, e,  , c, h, c, k, e, n,  , c]       320
# 28       28  [f, r,  , w, h,  , p, r, g, u, ,,  , l, e, e, ...       369
# 29       29  [C, h, c, k, e, n,  , n,  , b, r, c, c, l,  , ...       584
# 30       30  [g, r, l, c, ,,  , u, g, e, ,,  , n,  , k, l, ...       498
# 31       31  [c, h, c, k, e, n,  , c, p, r, e, e,  , n, w, ...       667
# 32       32      [c, r, e,  , h, r, p,  , n,  , u, h, r,  , p]       444
# 33       33  [B, l, c, k,  , B, e, n,  , n,  , u, h, r,  , ...       430
# 34       34         [v, e, g, n,  , u, h, r,  , r, g, n, f, f]       430
# 35       35  [k, l, l, e,  , e, k,  , w, h,  , u, h, r,  , ...       231
# 36       36  [c, h, e, e,  , g, r, u, n,  , b, e, e, f,  , ...       351
# 37       37                                 [b, r, e, k, f,  ]       365
# 38       38         [e, l,  , w, h,  , f, r, u,  , n,  , n, u]       341
# 39       39      [u, h, w, e,  , b, r, e, k, f,  , k, l, l, e]       341
# 40       40  [b, r, e, k, f,  , l,  , w, h,  , e, g, g,  , ...       527
# 41       41            [l, n,  , v, c,  , p, k, e,  , b, w, l]       442
# 42       42   [f, l, f, e, l,  , b, b, u, l, e, h,  , b, w, l]       416
# 43       43  [p, e, n, u,  , b, u, e, r,  , e, n, e, r, g, ...       174
# 44       44  [B, l, u, e, b, e, r, r, -, l, e, n,  , e, n, ...       190
# 45       45  [b, k, e,  , z, u, c, c, h, n,  , w, f, f, l, ...        84
# 46       46         [c, r, p,  , c, u, l, f, l, w, e, r,  , c]       157
# 47       47   [V, e, g, e, r, n,  , l, e, u, c, e,  , w, r, p]       178
# 48       48  [b, u, f, f, l,  , c, h, c, k, e, n,  , c, u, ...       189
# 49       49                     [c, h, c, k, e, n,  , p, c, c]       249
# 50       50  [w, e, e,  , n,  , u, r,  , p, r, k,  , w, h, ...       415
#
#     CARBS  PROTEIN  FAT               MEAL TYPE  \
# 0      22       17   16             side, lunch
# 1      11       52   29           dinner, lunch
# 2      22        7    8                    side
# 3      78       17   25           dinner, lunch
# 4      56       34   43           dinner, lunch
# 5       8       13   11     side, lunch, dinner
# 6      57       19   24           lunch, dinner
# 7      77       28   27           lunch, dinner
# 8       6       33   16           lunch, dinner
# 9       8       34    4           lunch, dinner
# 10      5        9    8  side, lunch, breakfast
# 11      1       19   15           entree, lunch
# 12      9       24   18     side, lunch, dinner
# 13     46       26   31           lunch, dinner
# 14     35       16   28     side, lunch, dinner
# 15     30       11   24             side, lunch
# 16     55       11    5     side, lunch, dinner
# 17     64       16   20           lunch, dinner
# 18      3       34   10                  entree
# 19     44        7   10                   snack
# 20     24        9   10           dinner, lunch
# 21     14       32   12           dinner, lunch
# 22     68       26   14           dinner, lunch
# 23     43       29   16           dinner, lunch
# 24      8        3    7             snack, side
# 25     23       10   11           dinner, lunch
# 26     26        8   16           dinner, lunch
# 27     34       34    7           dinner, lunch
# 28     14       18   27        breakfast, lunch
# 29     45       40   24                  dinner
# 30     33       30   28           dinner, lunch
# 31     41       42   38           lunch, dinner
# 32     50       37   14           lunch, dinner
# 33     49       13   21                  dinner
# 34     55       12   18                  dinner
# 35     18       26    7                  dinner
# 36     11       26   23                  dinner
# 37     40       15   19               breakfast
# 38     47       22    8               breakfast
# 39     23       17   20               breakfast
# 40     37       16   34               breakfast
# 41     34       30   22           lunch, dinner
# 42     37       11   26                   lunch
# 43     18        4    9                   snack
# 44     27        4    9                   snack
# 45      7        4    5                   snack
# 46     23        5    5           lunch, dinner
# 47     11       13   11           lunch, dinner
# 48      7       21    7           lunch, dinner
# 49     10       27   10                  entree
# 50     13       29   28                  entree
#
#                                MAIN FLAVORS  \
# 0                 [cabbage, ramen, chicken]
# 1              [pork, tomato, sazon, adobo]
# 2                 [squash, zuccini, cheese]
# 3                 [beef, tomato, chickpeas]
# 4                 [peanut, ginger, chicken]
# 5                            [tofu, chilli]
# 6                  [sausage, pasta, pepper]
# 7          [spinach, creamcheese, tomatoes]
# 8              [tilapia, coleslaw, avocado]
# 9              [tilapia, zucchini, paprika]
# 10           [mushrooms, asparagus, pepper]
# 11                           [salmon, sage]
# 12                  [chicken, egg, lettuce]
# 13                 [spinach, beans, pepper]
# 14        [mushrooms, lentils, coconutmilk]
# 15        [cauliflower, paprika, chickpeas]
# 16                 [tomato, beans, spinach]
# 17             [chickpeas, cabbage, tahini]
# 18                 [chicken, lemon, pepper]
# 19                  [oats, dates, cinnamon]
# 20              [lemon, broccoli, parmesan]
# 21            [seabass, orange, grapefruit]
# 22              [shrimp, pineapple, pepper]
# 23              [chicken, bellpepper, corn]
# 24        [cauliflower, sriracha, hotsauce]
# 25     [spaghettisquash, spinach, parmesan]
# 26        [cauliflower, cinnamon, turmeric]
# 27                    [chicken, lime, corn]
# 28                   [leek, asparagus, egg]
# 29           [chicken, broccoli, brownrice]
# 30             [turkey, mozzarella, garlic]
# 31            [chicken, tomato, mozzarella]
# 32              [shrimp, mushroom, cashews]
# 33  [mushrooms, blackbeans, enchiladasauce]
# 34     [mushrooms, dijonmustard, whitewine]
# 35             [mushrooms, steak, broccoli]
# 36                  [beef, jalapeno, chili]
# 37         [blackbeans, egg, tacoseasoning]
# 38                     [oat, yogurt, apple]
# 39              [bacon, potato, bellpepper]
# 40       [avocado, kidneybeans, saladgreen]
# 41              [salmon, brownrice, tamari]
# 42           [falafel, tabbouleh, tzatziki]
# 43          [peanutbutter, oats, chocolate]
# 44                   [oats, lemon, walnuts]
# 45                [zucchini, oldbay, lemon]
# 46     [cauliflower, refriedbeans, cabbage]
# 47               [mushrooms, lettuce, tofu]
# 48          [hotsauce, chicken, bluecheese]
# 49                 [chicken, lemon, garlic]
# 50              [pork, soysauce, scallions]
#
#                                    TAGS  \
# 0                                [meat]
# 1                                [meat]
# 2                   [dairy, vegetables]
# 3                                [meat]
# 4                       [peanuts, meat]
# 5                   [vegetarian, vegan]
# 6                                [meat]
# 7                          [vegetarian]
# 8                          [keto, fish]
# 9              [keto, vegetables, fish]
# 10  [keto, vegetarian, vegetables, egg]
# 11                         [keto, fish]
# 12                   [keto, vegetables]
# 13                         [vegetarian]
# 14                  [vegetarian, vegan]
# 15             [vegetarian, vegetables]
# 16                 [vegetarian, lowfat]
# 17                         [vegetarian]
# 18                         [keto, meat]
# 19                         [wholegrain]
# 20                         [vegetarian]
# 21                  [keto, fish, fruit]
# 22             [fish, shellfish, fruit]
# 23           [meat, highprotein, fruit]
# 24                  [vegetarian, spicy]
# 25      [vegetarian, vegetables, dairy]
# 26             [vegetarian, vegetables]
# 27           [meat, wholegrain, lowfat]
# 28  [keto, vegetables, vegetarian, egg]
# 29             [vegetables, wholegrain]
# 30            [meat, wholegrain, dairy]
# 31                   [meat, wholegrain]
# 32  [nuts, fish, shellfish, wholewheat]
# 33      [vegetarian, dairy, wholegrain]
# 34                  [vegan, wholewheat]
# 35                               [meat]
# 36            [meat, vegetables, spicy]
# 37        [egg, vegetarian, wholegrain]
# 38                  [dairy, vegetarian]
# 39                          [meat, egg]
# 40        [vegetables, vegetarian, egg]
# 41                   [fish, wholegrain]
# 42                         [vegetarian]
# 43                [vegetarian, peanuts]
# 44                  [vegetarian, vegan]
# 45                    [vegetarian, egg]
# 46                [vegan, vegetarian, ]
# 47                [vegetarian, lowcarb]
# 48                  [spicy, keto, meat]
# 49                         [keto, meat]
# 50                               [meat]
#
#                                      combinedFeatures
# 0                          cabbage ramen chicken meat
# 1                        pork tomato sazon adobo meat
# 2              squash zuccini cheese dairy vegetables
# 3                          beef tomato chickpeas meat
# 4                  peanut ginger chicken peanuts meat
# 5                        tofu chilli vegetarian vegan
# 6                           sausage pasta pepper meat
# 7             spinach creamcheese tomatoes vegetarian
# 8                  tilapia coleslaw avocado keto fish
# 9       tilapia zucchini paprika keto vegetables fish
# 10  mushrooms asparagus pepper keto vegetarian veg...
# 11                              salmon sage keto fish
# 12                chicken egg lettuce keto vegetables
# 13                    spinach beans pepper vegetarian
# 14     mushrooms lentils coconutmilk vegetarian vegan
# 15  cauliflower paprika chickpeas vegetarian veget...
# 16             tomato beans spinach vegetarian lowfat
# 17                chickpeas cabbage tahini vegetarian
# 18                     chicken lemon pepper keto meat
# 19                     oats dates cinnamon wholegrain
# 20                 lemon broccoli parmesan vegetarian
# 21          seabass orange grapefruit keto fish fruit
# 22       shrimp pineapple pepper fish shellfish fruit
# 23     chicken bellpepper corn meat highprotein fruit
# 24     cauliflower sriracha hotsauce vegetarian spicy
# 25  spaghettisquash spinach parmesan vegetarian ve...
# 26  cauliflower cinnamon turmeric vegetarian veget...
# 27           chicken lime corn meat wholegrain lowfat
# 28  leek asparagus egg keto vegetables vegetarian egg
# 29   chicken broccoli brownrice vegetables wholegrain
# 30     turkey mozzarella garlic meat wholegrain dairy
# 31          chicken tomato mozzarella meat wholegrain
# 32  shrimp mushroom cashews nuts fish shellfish wh...
# 33  mushrooms blackbeans enchiladasauce vegetarian...
# 34  mushrooms dijonmustard whitewine vegan wholewheat
# 35                      mushrooms steak broccoli meat
# 36          beef jalapeno chili meat vegetables spicy
# 37  blackbeans egg tacoseasoning egg vegetarian wh...
# 38                  oat yogurt apple dairy vegetarian
# 39                   bacon potato bellpepper meat egg
# 40  avocado kidneybeans saladgreen vegetables vege...
# 41            salmon brownrice tamari fish wholegrain
# 42              falafel tabbouleh tzatziki vegetarian
# 43     peanutbutter oats chocolate vegetarian peanuts
# 44                oats lemon walnuts vegetarian vegan
# 45               zucchini oldbay lemon vegetarian egg
# 46  cauliflower refriedbeans cabbage vegan vegetar...
# 47          mushrooms lettuce tofu vegetarian lowcarb
# 48        hotsauce chicken bluecheese spicy keto meat
# 49                     chicken lemon garlic keto meat
# 50                       pork soysauce scallions meat

# %%
# combine the features we'll be using to find content similarity
# TODO: include 'name' in here at some point. Will need to strip out stop words and symbols like '&' and 'w/'
#     once that processing has been done though, can probably just be concatenated with the rest
def combine(x):
    return ' '.join(x['MAIN FLAVORS']) + ' '+ ' '.join(x['TAGS'])

df['combinedFeatures'] = df.apply(combine, axis=1)

# print(df[['combinedFeatures']]).head(2)

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['combinedFeatures'])

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix) # this is passed into hybrid()
#cosine_sim = surprise.Dataset.load_from_df()

# %%
#collaborative filtering
reader = Reader()
data=Dataset.load_from_df(df_ratings[['user_id', 'meal_id', 'rating']], reader)

# %%
trainset, testset = train_test_split(data, test_size=0.3, random_state=10)

# %%
svd = SVD()
svd.fit(trainset)

# %%
test_pred = svd.test(testset)

# %%
accuracy.rmse(test_pred, verbose=True) # generated rmse of 1.4 isn't great, need more data
# Out:
# RMSE: 1.4420
# 1.4420373180059407

# %%
r_id = df_ratings['user_id'].values[0]
m_id = df_ratings['meal_id'].values[0]
n_recs = 5

print(m_id)
# Out:
# 5

# %%
def hybrid(user_id, meal_id, n_recs, df, ratings, cosine_sim, svd_model):
    
        # find 50 most similar meals
        similarity = list(enumerate(cosine_sim[int(meal_id)]))
        similarity = sorted(similarity, key=lambda x:x[1], reverse=True)
        similarity = similarity[1:50] # select the first 50 similar values, likely don't want so many but this is a good starting point
    
        #print(similarity)
        
        # get the metadata of THIS meal
        meal_index = [i[0] for i in similarity]
        
        #print(meal_index)
        #print(df)
        meals = df.iloc[meal_index][['meal_id']]# get all the meal_ids#, 'user_id', 'rating']] 
        meals = meals.merge(ratings, on='meal_id') # merge with the ratings
        print(meals)
  
        
        # predict similar values using svd_model
        meals['est'] = meals.apply(lambda x: svd_model.predict(user_id, x['meal_id'], x['rating']).est, axis =1)
        
        #sort predictions in decreasing order; return the number of recommendations requested
        meals = meals.sort_values('est', ascending=False)
        return meals.head(n_recs)

# %%
df.merge(df_ratings, on="meal_id")

hybrid(r_id, m_id, n_recs, df, df_ratings, cosine_sim, svd)
# Out:
#     meal_id  user_id  rating
# 0        14        2     4.5
# 1        44        8     4.5
# 2         7        1     4.5
# 3        17        8     3.5
# 4        20        1     5.0
# 5        20        8     4.0
# 6        20        9     5.0
# 7        42        8     5.0
# 8        15        5     2.0
# 9        15        8     1.0
# 10       15        9     2.0
# 11       16        8     3.0
# 12       24        1     2.0
# 13       24        5     2.5
# 14       24        6     4.5
# 15       26        6     4.0
# 16       34        2     4.5
# 17       38        6     2.0
# 18       25        1     4.5
# 19       33        8     3.0
# 20       10        1     4.0
# 21       10        2     3.0
# 22       37        1     2.0
# 23       28        1     3.5
# 24       28        2     2.0
# 25       28        9     2.0
# 26        0        9     4.0
# 27        1        6     5.0
# 28        3        2     4.0
# 29        3        9     4.0
# 30        4        9     3.5
# 31        8        9     1.0
# 32       11        5     4.5
# 33       11        6     3.0
# 34       18        8     5.0
# 35       19        8     2.0
# 36       21        6     2.5
# 37       21        8     4.5
# 38       22        5     1.5
# 39       22        6     2.0
# 40       27        8     4.0
# 41       31        2     2.0
# 42       32        1     2.5
# 43       36        6     4.0
# 44       41        5     4.0
# 45       41        9     4.0
#     meal_id  user_id  rating       est
# 2         7        1     4.5  3.670316
# 18       25        1     4.5  3.600909
# 44       41        5     4.0  3.565734
# 45       41        9     4.0  3.565734
# 16       34        2     4.5  3.505866

# %%
print(df)
print(df_ratings)
